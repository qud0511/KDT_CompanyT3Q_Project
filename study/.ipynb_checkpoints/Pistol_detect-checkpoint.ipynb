# %% [markdown]
# ## Module Loading

# %%
from glob import glob

# %% [markdown]
# ## Code

# %%
# 이미지 파일 리스트 생성
img_list = glob(r'../data/Pistol_dataset/export/images/*.jpg')
print(f'Image 갯수: {len(img_list)}')
# Out:
# Image 갯수: 0

# %%
# train/validation dataset 분리
from sklearn.model_selection import train_test_split

train_img_list, val_img_list = train_test_split(img_list,
                                                test_size=0.2,
                                                random_state=42)
print(f'train_img_list 갯수: {len(train_img_list)}, val_img_list 갯수: {len(val_img_list)}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [3], line 4
#       1 # train/validation dataset 분리
#       2 from sklearn.model_selection import train_test_split
# ----> 4 train_img_list, val_img_list = train_test_split(img_list,
#       5                                                 test_size=0.2,
#       6                                                 random_state=42)
#       7 print(f'train_img_list 갯수: {len(train_img_list)}, val_img_list 갯수: {len(val_img_list)}')
#
# File c:\Users\LG\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_split.py:2448, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2445 arrays = indexable(*arrays)
#    2447 n_samples = _num_samples(arrays[0])
# -> 2448 n_train, n_test = _validate_shuffle_split(
#    2449     n_samples, test_size, train_size, default_test_size=0.25
#    2450 )
#    2452 if shuffle is False:
#    2453     if stratify is not None:
#
# File c:\Users\LG\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_split.py:2126, in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    2123 n_train, n_test = int(n_train), int(n_test)
#    2125 if n_train == 0:
# -> 2126     raise ValueError(
#    2127         "With n_samples={}, test_size={} and train_size={}, the "
#    2128         "resulting train set will be empty. Adjust any of the "
#    2129         "aforementioned parameters.".format(n_samples, test_size, train_size)
#    2130     )
#    2132 return n_train, n_test
#
# ValueError: With n_samples=0, test_size=0.2 and train_size=None, the resulting train set will be empty. Adjust any of the aforementioned parameters.

# %%
# train/val 이미지 경로 txt파일로 저장
with open(r'../data/Pistol_dataset/train.txt', 'w') as f:
    f.write('\n'.join(train_img_list) + '\n')

with open(r'../data/Pistol_dataset/val.txt', 'w') as f:
    f.write('\n'.join(val_img_list) + '\n')

# %%
# ymal 파일 정보 확인
import yaml

with open('../data/Pistol_dataset/data.yaml', 'r') as f:
    data = yaml.full_load(f)

print(f'data.yaml 파일 정보: {data}')

data['train'] = r'../data/Pistol_dataset/train.txt'
data['val'] = r'../data/Pistol_dataset/val.txt'

with open('../data/Pistol_dataset/data.yaml', 'w') as f:
    yaml.dump(data, f)

print(data)
# Out:
# data.yaml 파일 정보: {'train': '../train/images', 'val': '../valid/images', 'nc': 1, 'names': ['pistol']}
# {'train': '../data/Pistol_dataset/train.txt', 'val': '../data/Pistol_dataset/val.txt', 'nc': 1, 'names': ['pistol']}

# %% [markdown]
# ## Model Training

# %% [markdown]
# cd C:\DataScience\T3Q\yolo_v5
# python train.py --img 416 --batch 16 --epochs 50 --data C:\DataScience\T3Q\data\Pistol_dataset\data.yaml --cfg C:\DataScience\T3Q\yolo_v5\models\yolov5s.yaml --weights yolov5s.pt --name gun_yolov5s_results

# %% [markdown]
# python train.py --img 416 --batch 16 --epochs 50 --data C:\data\pistol\data.yaml --cfg C:\Users\LG\Git_PBJ\yolov5\models\yolov5m.yaml --weights yolov5m.pt --name gun_yolov5m_result
